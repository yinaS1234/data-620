# %% [markdown]
# # Data 620 - Web Analytics HW 5.2-Document Classification
#
# **Yina Qiao**
#
#
# Assignment:
#
# It can be useful to be able to classify new "test" documents using already classified "training" documents.  A common example is using a corpus of labeled spam and ham (non-spam) e-mails to predict whether or not a new document is spam.  Here is one example of such data:  [UCI Machine Learning Repository: Spambase Data Set](http://archive.ics.uci.edu/ml/datasets/Spambase)
#
# For this project, you can either use the above dataset to predict the class of new documents (either withheld from the training dataset or from another source such as your own spam folder).
#
# For more adventurous students, you are welcome (encouraged!) to come up a different set of documents (including scraped web pages!?) that have already been classified (e.g. tagged), then analyze these documents to predict how new documents should be classified.

# %% [markdown]
# ## Data
#
# Source: http://archive.ics.uci.edu/ml/datasets/Spambase

# %% [markdown]
# ## Data preparation and load

# %%
import tempfile
import urllib.request
import zipfile
import os
import pandas as pd
import nltk
import numpy as np


from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn import ensemble
from sklearn import svm
import sklearn.metrics as sm

# Define the URL of the ZIP file to download
url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/spambase/spambase.zip'

# Create a temporary file to store the downloaded ZIP file
temp = tempfile.NamedTemporaryFile()

# Download the ZIP file from the URL
urllib.request.urlretrieve(url, temp.name)

# Extract the contents of the ZIP file to a directory named 'l1'
with zipfile.ZipFile(temp.name, 'r') as zip_ref:
    zip_ref.extractall('./l1')

# Change the current working directory to 'l1'
os.chdir('l1')

# Read the 'spambase.data' file into a DataFrame
spambase = pd.read_csv("spambase.data", sep=",")

# Read the column names from the 'spambase.names' file, removing punctuation
cnames = pd.read_csv("spambase.names", comment="|", header=None)[0]
cnames = cnames.str.replace("[[:punct:]]", "").tolist()

# Adjust the column names, excluding the first entry, and add 'target' as the last column name
cnames = cnames[1:] + ["target"]

# Assign the adjusted column names to the DataFrame
spambase.columns = cnames
# Out:
# <ipython-input-1-83847604bf3b>:37: FutureWarning: The default value of regex will change from True to False in a future version.
#   cnames = cnames.str.replace("[[:punct:]]", "").tolist()
# /usr/local/lib/python3.10/dist-packages/pandas/core/strings/object_array.py:158: FutureWarning: Possible nested set at position 1
#   pat = re.compile(pat, flags=flags)

# %% [markdown]
# ## Data exploration

# %%
# Looking at first few rows
spambase.head()
# Out:
#    word_freq_make:         continuous.  word_freq_address:      continuous.  \
# 0                                 0.21                                 0.28
# 1                                 0.06                                 0.00
# 2                                 0.00                                 0.00
# 3                                 0.00                                 0.00
# 4                                 0.00                                 0.00
#
#    word_freq_all:          continuous.  word_freq_3d:           continuous.  \
# 0                                 0.50                                  0.0
# 1                                 0.71                                  0.0
# 2                                 0.00                                  0.0
# 3                                 0.00                                  0.0
# 4                                 0.00                                  0.0
#
#    word_freq_our:          continuous.  word_freq_over:         continuous.  \
# 0                                 0.14                                 0.28
# 1                                 1.23                                 0.19
# 2                                 0.63                                 0.00
# 3                                 0.63                                 0.00
# 4                                 1.85                                 0.00
#
#    word_freq_remove:       continuous.  word_freq_internet:     continuous.  \
# 0                                 0.21                                 0.07
# 1                                 0.19                                 0.12
# 2                                 0.31                                 0.63
# 3                                 0.31                                 0.63
# 4                                 0.00                                 1.85
#
#    word_freq_order:        continuous.  word_freq_mail:         continuous.  \
# 0                                 0.00                                 0.94
# 1                                 0.64                                 0.25
# 2                                 0.31                                 0.63
# 3                                 0.31                                 0.63
# 4                                 0.00                                 0.00
#
#    ...  char_freq_;:            continuous.  \
# 0  ...                                 0.00
# 1  ...                                 0.01
# 2  ...                                 0.00
# 3  ...                                 0.00
# 4  ...                                 0.00
#
#    char_freq_(:            continuous.  char_freq_[:            continuous.  \
# 0                                0.132                                  0.0
# 1                                0.143                                  0.0
# 2                                0.137                                  0.0
# 3                                0.135                                  0.0
# 4                                0.223                                  0.0
#
#    char_freq_!:            continuous.  char_freq_$:            continuous.  \
# 0                                0.372                                0.180
# 1                                0.276                                0.184
# 2                                0.137                                0.000
# 3                                0.135                                0.000
# 4                                0.000                                0.000
#
#    char_freq_#:            continuous.  \
# 0                                0.048
# 1                                0.010
# 2                                0.000
# 3                                0.000
# 4                                0.000
#
#    capital_run_length_average: continuous.  \
# 0                                    5.114
# 1                                    9.821
# 2                                    3.537
# 3                                    3.537
# 4                                    3.000
#
#    capital_run_length_longest: continuous.  \
# 0                                      101
# 1                                      485
# 2                                       40
# 3                                       40
# 4                                       15
#
#    capital_run_length_total:   continuous.  target
# 0                                     1028       1
# 1                                     2259       1
# 2                                      191       1
# 3                                      191       1
# 4                                       54       1
#
# [5 rows x 58 columns]

# %%
spambase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 58 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   word_freq_make:         continuous.      4600 non-null   float64
#  1   word_freq_address:      continuous.      4600 non-null   float64
#  2   word_freq_all:          continuous.      4600 non-null   float64
#  3   word_freq_3d:           continuous.      4600 non-null   float64
#  4   word_freq_our:          continuous.      4600 non-null   float64
#  5   word_freq_over:         continuous.      4600 non-null   float64
#  6   word_freq_remove:       continuous.      4600 non-null   float64
#  7   word_freq_internet:     continuous.      4600 non-null   float64
#  8   word_freq_order:        continuous.      4600 non-null   float64
#  9   word_freq_mail:         continuous.      4600 non-null   float64
#  10  word_freq_receive:      continuous.      4600 non-null   float64
#  11  word_freq_will:         continuous.      4600 non-null   float64
#  12  word_freq_people:       continuous.      4600 non-null   float64
#  13  word_freq_report:       continuous.      4600 non-null   float64
#  14  word_freq_addresses:    continuous.      4600 non-null   float64
#  15  word_freq_free:         continuous.      4600 non-null   float64
#  16  word_freq_business:     continuous.      4600 non-null   float64
#  17  word_freq_email:        continuous.      4600 non-null   float64
#  18  word_freq_you:          continuous.      4600 non-null   float64
#  19  word_freq_credit:       continuous.      4600 non-null   float64
#  20  word_freq_your:         continuous.      4600 non-null   float64
#  21  word_freq_font:         continuous.      4600 non-null   float64
#  22  word_freq_000:          continuous.      4600 non-null   float64
#  23  word_freq_money:        continuous.      4600 non-null   float64
#  24  word_freq_hp:           continuous.      4600 non-null   float64
#  25  word_freq_hpl:          continuous.      4600 non-null   float64
#  26  word_freq_george:       continuous.      4600 non-null   float64
#  27  word_freq_650:          continuous.      4600 non-null   float64
#  28  word_freq_lab:          continuous.      4600 non-null   float64
#  29  word_freq_labs:         continuous.      4600 non-null   float64
#  30  word_freq_telnet:       continuous.      4600 non-null   float64
#  31  word_freq_857:          continuous.      4600 non-null   float64
#  32  word_freq_data:         continuous.      4600 non-null   float64
#  33  word_freq_415:          continuous.      4600 non-null   float64
#  34  word_freq_85:           continuous.      4600 non-null   float64
#  35  word_freq_technology:   continuous.      4600 non-null   float64
#  36  word_freq_1999:         continuous.      4600 non-null   float64
#  37  word_freq_parts:        continuous.      4600 non-null   float64
#  38  word_freq_pm:           continuous.      4600 non-null   float64
#  39  word_freq_direct:       continuous.      4600 non-null   float64
#  40  word_freq_cs:           continuous.      4600 non-null   float64
#  41  word_freq_meeting:      continuous.      4600 non-null   float64
#  42  word_freq_original:     continuous.      4600 non-null   float64
#  43  word_freq_project:      continuous.      4600 non-null   float64
#  44  word_freq_re:           continuous.      4600 non-null   float64
#  45  word_freq_edu:          continuous.      4600 non-null   float64
#  46  word_freq_table:        continuous.      4600 non-null   float64
#  47  word_freq_conference:   continuous.      4600 non-null   float64
#  48  char_freq_;:            continuous.      4600 non-null   float64
#  49  char_freq_(:            continuous.      4600 non-null   float64
#  50  char_freq_[:            continuous.      4600 non-null   float64
#  51  char_freq_!:            continuous.      4600 non-null   float64
#  52  char_freq_$:            continuous.      4600 non-null   float64
#  53  char_freq_#:            continuous.      4600 non-null   float64
#  54  capital_run_length_average: continuous.  4600 non-null   float64
#  55  capital_run_length_longest: continuous.  4600 non-null   int64
#  56  capital_run_length_total:   continuous.  4600 non-null   int64
#  57  target                                   4600 non-null   int64
# dtypes: float64(55), int64(3)
# memory usage: 2.0 MB

# %%
spambase.describe()
# Out:
#        word_freq_make:         continuous.  \
# count                          4600.000000
# mean                              0.104576
# std                               0.305387
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               4.540000
#
#        word_freq_address:      continuous.  \
# count                          4600.000000
# mean                              0.212922
# std                               1.290700
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                              14.280000
#
#        word_freq_all:          continuous.  \
# count                          4600.000000
# mean                              0.280578
# std                               0.504170
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.420000
# max                               5.100000
#
#        word_freq_3d:           continuous.  \
# count                          4600.000000
# mean                              0.065439
# std                               1.395303
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                              42.810000
#
#        word_freq_our:          continuous.  \
# count                          4600.000000
# mean                              0.312222
# std                               0.672586
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.382500
# max                              10.000000
#
#        word_freq_over:         continuous.  \
# count                          4600.000000
# mean                              0.095922
# std                               0.273850
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               5.880000
#
#        word_freq_remove:       continuous.  \
# count                          4600.000000
# mean                              0.114233
# std                               0.391480
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               7.270000
#
#        word_freq_internet:     continuous.  \
# count                          4600.000000
# mean                              0.105317
# std                               0.401112
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                              11.110000
#
#        word_freq_order:        continuous.  \
# count                          4600.000000
# mean                              0.090087
# std                               0.278643
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               5.260000
#
#        word_freq_mail:         continuous.  ...  \
# count                          4600.000000  ...
# mean                              0.239465  ...
# std                               0.644816  ...
# min                               0.000000  ...
# 25%                               0.000000  ...
# 50%                               0.000000  ...
# 75%                               0.160000  ...
# max                              18.180000  ...
#
#        char_freq_;:            continuous.  \
# count                          4600.000000
# mean                              0.038583
# std                               0.243497
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               4.385000
#
#        char_freq_(:            continuous.  \
# count                          4600.000000
# mean                              0.139061
# std                               0.270377
# min                               0.000000
# 25%                               0.000000
# 50%                               0.065000
# 75%                               0.188000
# max                               9.752000
#
#        char_freq_[:            continuous.  \
# count                          4600.000000
# mean                              0.016980
# std                               0.109406
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                               4.081000
#
#        char_freq_!:            continuous.  \
# count                          4600.000000
# mean                              0.268960
# std                               0.815726
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.314250
# max                              32.478000
#
#        char_freq_$:            continuous.  \
# count                          4600.000000
# mean                              0.075827
# std                               0.245906
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.052000
# max                               6.003000
#
#        char_freq_#:            continuous.  \
# count                          4600.000000
# mean                              0.044248
# std                               0.429388
# min                               0.000000
# 25%                               0.000000
# 50%                               0.000000
# 75%                               0.000000
# max                              19.829000
#
#        capital_run_length_average: continuous.  \
# count                              4600.000000
# mean                                  5.191827
# std                                  31.732891
# min                                   1.000000
# 25%                                   1.588000
# 50%                                   2.275500
# 75%                                   3.705250
# max                                1102.500000
#
#        capital_run_length_longest: continuous.  \
# count                              4600.000000
# mean                                 52.170870
# std                                 194.912453
# min                                   1.000000
# 25%                                   6.000000
# 50%                                  15.000000
# 75%                                  43.000000
# max                                9989.000000
#
#        capital_run_length_total:   continuous.       target
# count                              4600.000000  4600.000000
# mean                                283.290435     0.393913
# std                                 606.413764     0.488669
# min                                   1.000000     0.000000
# 25%                                  35.000000     0.000000
# 50%                                  95.000000     0.000000
# 75%                                 265.250000     1.000000
# max                               15841.000000     1.000000
#
# [8 rows x 58 columns]

# %% [markdown]
# ## Spam / non-spam count
#
# The last column spamclass contain whether a email is spam or not.
#
# 1 = denotes whether the e-mail was considered spam (1) or not (0), i.e. unsolicited commercial e-mail.

# %%
spam_count = len(spambase[spambase['target'] == 1])
notspam_count = len(spambase[spambase['target'] == 0])

print("Spam count: %d" % spam_count)
print("Non-spam count: %d" % notspam_count)
# Out:
# Spam count: 1812
# Non-spam count: 2788

# %% [markdown]
# #### Check for nulls

# %%
spambase[spambase.isnull().any(axis = 1)]
# Out:
# Empty DataFrame
# Columns: [word_freq_make:         continuous., word_freq_address:      continuous., word_freq_all:          continuous., word_freq_3d:           continuous., word_freq_our:          continuous., word_freq_over:         continuous., word_freq_remove:       continuous., word_freq_internet:     continuous., word_freq_order:        continuous., word_freq_mail:         continuous., word_freq_receive:      continuous., word_freq_will:         continuous., word_freq_people:       continuous., word_freq_report:       continuous., word_freq_addresses:    continuous., word_freq_free:         continuous., word_freq_business:     continuous., word_freq_email:        continuous., word_freq_you:          continuous., word_freq_credit:       continuous., word_freq_your:         continuous., word_freq_font:         continuous., word_freq_000:          continuous., word_freq_money:        continuous., word_freq_hp:           continuous., word_freq_hpl:          continuous., word_freq_george:       continuous., word_freq_650:          continuous., word_freq_lab:          continuous., word_freq_labs:         continuous., word_freq_telnet:       continuous., word_freq_857:          continuous., word_freq_data:         continuous., word_freq_415:          continuous., word_freq_85:           continuous., word_freq_technology:   continuous., word_freq_1999:         continuous., word_freq_parts:        continuous., word_freq_pm:           continuous., word_freq_direct:       continuous., word_freq_cs:           continuous., word_freq_meeting:      continuous., word_freq_original:     continuous., word_freq_project:      continuous., word_freq_re:           continuous., word_freq_edu:          continuous., word_freq_table:        continuous., word_freq_conference:   continuous., char_freq_;:            continuous., char_freq_(:            continuous., char_freq_[:            continuous., char_freq_!:            continuous., char_freq_$:            continuous., char_freq_#:            continuous., capital_run_length_average: continuous., capital_run_length_longest: continuous., capital_run_length_total:   continuous., target]
# Index: []
#
# [0 rows x 58 columns]

# %% [markdown]
# ## Data Preparation
#
# Let's split the data into train and test, distributing 70% in train.

# %%
spambase_rows = len(spambase)
train_rows = int(spambase_rows * 0.7)
val_rows = int(spambase_rows * 0.15)
test_rows = spambase_rows - train_rows - val_rows

# %%
print("Training rows (70 prc of total): %d" %train_rows)
print("Validation rows (15 prc of total): %d" %val_rows)
print("Testing rows (15 prc of total): %d" %test_rows)
print("Total: %d" %(train_rows + val_rows + test_rows))
# Out:
# Training rows (70 prc of total): 3220
# Validation rows (15 prc of total): 690
# Testing rows (15 prc of total): 690
# Total: 4600

# %%
train_set, test_set = train_test_split(spambase, test_size = test_rows, random_state = 8)
train_set, val_set = train_test_split(train_set, test_size = val_rows, random_state = 88)

# %%
print("Training set: %d" %len(train_set))
print("Validation set: %d" %len(val_set))
print("Testing set: %d" %len(test_set))
print("Total: %d" %(len(train_set) + len(val_set) + len(test_set)))
# Out:
# Training set: 3220
# Validation set: 690
# Testing set: 690
# Total: 4600

# %% [markdown]
# ## Confusion Matrix
#
# We will compute Confusion Matrix using following function, which will give us True Positives (TP), True Negatives (TN), False Positives (FP) and False Negatives (FN), from which the "Accuracy" of an algorithm can be determined.

# %%
def func_confusion_matrix(y_true, y_pred):
    cm = sm.confusion_matrix(y_true, y_pred, labels = [1, 0])
    print("TP: %d" %cm[0,0])
    print("FP: %d" %cm[1,0])
    print("TN: %d" %cm[1,1])
    print("FN: %d" %cm[0,1])
    print(sm.classification_report(y_true, y_pred, labels = [1,0], target_names = ["Spam", "Not spam"]))
    return cm

# %% [markdown]
# ## Decision Tree
#
# Decision Trees (DTs) are a non-parametric supervised learning method used for classification and regression. The goal is to create a model that predicts the value of a target variable by learning simple decision rules inferred from the data features. A tree can be seen as a piecewise constant approximation.
# Source: https://scikit-learn.org/stable/modules/tree.html

# %%
tree = tree.DecisionTreeClassifier(criterion = "entropy", random_state = 88)

# %% [markdown]
# ### Training Set

# %%
train_class = train_set['target']  # Replace 'spamclass' with the correct column name
train_vars = train_set.drop(labels='target', axis=1)  # Replace 'spamclass' with the correct column name

tree_fit = tree.fit(train_vars, train_class)

tree_train = tree_fit.predict(train_vars)
cm = func_confusion_matrix(train_class, tree_train)
# Out:
# TP: 1252
# FP: 0
# TN: 1967
# FN: 1
#               precision    recall  f1-score   support
#
#         Spam       1.00      1.00      1.00      1253
#     Not spam       1.00      1.00      1.00      1967
#
#     accuracy                           1.00      3220
#    macro avg       1.00      1.00      1.00      3220
# weighted avg       1.00      1.00      1.00      3220

# %% [markdown]
# ### Validation set

# %%
validate_class = val_set['target']  # Replace 'spamclass' with the correct column name
validate_vars = val_set.drop(labels='target', axis=1)  # Replace 'spamclass' with the correct column name

tree_validate = tree_fit.predict(validate_vars)
cm = func_confusion_matrix(validate_class, tree_validate)
# Out:
# TP: 244
# FP: 31
# TN: 388
# FN: 27
#               precision    recall  f1-score   support
#
#         Spam       0.89      0.90      0.89       271
#     Not spam       0.93      0.93      0.93       419
#
#     accuracy                           0.92       690
#    macro avg       0.91      0.91      0.91       690
# weighted avg       0.92      0.92      0.92       690

# %% [markdown]
# ### Test set

# %%
test_class = test_set['target']  # Replace 'spamclass' with the correct column name
test_vars = test_set.drop(labels='target', axis=1)  # Replace 'spamclass' with the correct column name

tree_test = tree_fit.predict(test_vars)
cm = func_confusion_matrix(test_class, tree_test)
# Out:
# TP: 262
# FP: 29
# TN: 373
# FN: 26
#               precision    recall  f1-score   support
#
#         Spam       0.90      0.91      0.91       288
#     Not spam       0.93      0.93      0.93       402
#
#     accuracy                           0.92       690
#    macro avg       0.92      0.92      0.92       690
# weighted avg       0.92      0.92      0.92       690

# %% [markdown]
# **Precision**
# Precision attempts to answer the following question:
# What proportion of positive identifications was actually correct?
#
# **Recall**
# Recall attempts to answer the following question:
# What proportion of actual positives was identified correctly?

# %% [markdown]
# ### Variable importance

# %%
def func_arrange_feature_by_importance(fit, vars):
    df = {'variable': pd.Series(vars.columns.values), 'imp': pd.Series(fit.feature_importances_)}
    return pd.DataFrame(df, columns=['variable','imp']).sort_values(['imp'], ascending=0).head(10)

func_arrange_feature_by_importance(tree_fit, test_vars)
# Out:
#                                    variable       imp
# 52      char_freq_$:            continuous.  0.268194
# 6       word_freq_remove:       continuous.  0.134915
# 51      char_freq_!:            continuous.  0.103756
# 24      word_freq_hp:           continuous.  0.078960
# 54  capital_run_length_average: continuous.  0.062309
# 55  capital_run_length_longest: continuous.  0.039214
# 15      word_freq_free:         continuous.  0.036289
# 26      word_freq_george:       continuous.  0.027385
# 44      word_freq_re:           continuous.  0.022259
# 56  capital_run_length_total:   continuous.  0.021100

# %% [markdown]
# ## Random Forest
# A random forest is a meta estimator that fits a number of decision tree classifiers on various sub-samples of the dataset and uses averaging to improve the predictive accuracy and control over-fitting. The sub-sample size is controlled with the max_samples parameter if bootstrap=True (default), otherwise the whole dataset is used to build each tree.
# Source: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html

# %%
forest = ensemble.RandomForestClassifier(criterion = "entropy", random_state = 88)

# %% [markdown]
# ### Training set

# %%
forest_fit = forest.fit(train_vars, train_class)

forest_train = forest_fit.predict(train_vars)
cm = func_confusion_matrix(train_class, forest_train)
# Out:
# TP: 1253
# FP: 1
# TN: 1966
# FN: 0
#               precision    recall  f1-score   support
#
#         Spam       1.00      1.00      1.00      1253
#     Not spam       1.00      1.00      1.00      1967
#
#     accuracy                           1.00      3220
#    macro avg       1.00      1.00      1.00      3220
# weighted avg       1.00      1.00      1.00      3220

# %% [markdown]
# ### Test set

# %%
forest_test = forest_fit.predict(test_vars)
cm = func_confusion_matrix(test_class, forest_test)
# Out:
# TP: 274
# FP: 21
# TN: 381
# FN: 14
#               precision    recall  f1-score   support
#
#         Spam       0.93      0.95      0.94       288
#     Not spam       0.96      0.95      0.96       402
#
#     accuracy                           0.95       690
#    macro avg       0.95      0.95      0.95       690
# weighted avg       0.95      0.95      0.95       690

# %%
func_arrange_feature_by_importance(forest_fit, test_vars)
# Out:
#                                    variable       imp
# 51      char_freq_!:            continuous.  0.099876
# 52      char_freq_$:            continuous.  0.098352
# 6       word_freq_remove:       continuous.  0.079624
# 54  capital_run_length_average: continuous.  0.066567
# 15      word_freq_free:         continuous.  0.063733
# 55  capital_run_length_longest: continuous.  0.056424
# 24      word_freq_hp:           continuous.  0.051010
# 20      word_freq_your:         continuous.  0.049192
# 56  capital_run_length_total:   continuous.  0.040445
# 18      word_freq_you:          continuous.  0.034850

# %% [markdown]
# ## Support Vector Machines
# SVM is an exciting algorithm and the concepts are relatively simple. The classifier separates data points using a hyperplane with the largest amount of margin. That's why an SVM classifier is also known as a discriminative classifier. SVM finds an optimal hyperplane which helps in classifying new data points.

# %%
svm = svm.SVC(random_state = 88)

# %% [markdown]
# ### Training set

# %%
svm_fit = svm.fit(train_vars, train_class)

svm_train = svm_fit.predict(train_vars)
cm = func_confusion_matrix(train_class, svm_train)
# Out:
# TP: 540
# FP: 210
# TN: 1757
# FN: 713
#               precision    recall  f1-score   support
#
#         Spam       0.72      0.43      0.54      1253
#     Not spam       0.71      0.89      0.79      1967
#
#     accuracy                           0.71      3220
#    macro avg       0.72      0.66      0.67      3220
# weighted avg       0.71      0.71      0.69      3220

# %% [markdown]
# ### Test Set

# %%
svm_test = svm_fit.predict(test_vars)
cm = func_confusion_matrix(test_class, svm_test)
# Out:
# TP: 129
# FP: 37
# TN: 365
# FN: 159
#               precision    recall  f1-score   support
#
#         Spam       0.78      0.45      0.57       288
#     Not spam       0.70      0.91      0.79       402
#
#     accuracy                           0.72       690
#    macro avg       0.74      0.68      0.68       690
# weighted avg       0.73      0.72      0.70       690

# %% [markdown]
# ## Conclusion
#
# So far, Random forest seems to be the best model.
